# %%
import pandas as pd

# %%
train_csv = pd.read_csv("../input/rsna-miccai-brain-tumor-radiogenomic-classification/train_labels.csv")

# %%
train_csv.head()

# %%
# Paitent ID's
train_csv["BraTS21ID"]

# %%
# 2 classes 
# Small Dataset 
train_csv["MGMT_value"].value_counts()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(5, 5))
sns.countplot(data=train_csv, x="MGMT_value");
# Not highly imbalanced
